# %%
import pandas as pd
from scipy.spatial import distance
import numpy as np
from geopy.distance import geodesic
from geopy.geocoders import Nominatim

# %%
UK_covid_df = pd.read_csv("UK_covid.csv")
UK_covid_df['coord'] = UK_covid_df[['lat','lon']].apply(tuple, axis=1)
UK_covid_df = UK_covid_df.drop(columns= ['lat', 'lon'])
UK_covid_df
# Out:
#              site  # death                                      coord
# 0            Adur       34         (50.84522125, -0.2939300331646212)
# 1       Allerdale       59          (54.70888095, -3.252788011003595)
# 2    Amber Valley       76   (53.02903840000001, -1.4625031096700565)
# 3            Arun       46  (50.830937799999994, -0.5666854639891136)
# 4        Ashfield      118            (56.21137289999999, -3.9614269)
# ..            ...      ...                                        ...
# 337      Wychavon       93          (52.1803417, -2.0623136726812445)
# 338       Wycombe       87          (51.66356185, -0.818083680966309)
# 339          Wyre       72         (59.11943975, -2.9708936400463584)
# 340   Wyre Forest      100         (52.38505915, -2.2347966141505187)
# 341          York      131  (53.959055500000005, -1.0815361000000001)
#
# [342 rows x 3 columns]

# %%
UK_pol_df = pd.read_csv("UK_pol_pop.csv")
UK_pol_df['coord'] = UK_pol_df[['lat','lon']].apply(tuple, axis=1)
UK_pol_df = UK_pol_df.drop(columns= ['lat', 'lon'])
UK_pol_df.head()
# Out:
#    Unnamed: 0               site        no2       pm10      pm2.5  Population  \
# 0           0           Aberdeen  21.323003  12.679401   7.534314      137962
# 1           1     Belfast Centre  29.134035  15.673754  10.273508      618108
# 2           2  Birmingham Tyburn  31.486575  18.136199  12.977897     2916458
# 3           3            Bristol  27.290171  17.094891  12.165736     1006600
# 4           4               Bury  64.735355  23.568150  18.968763     2798000
#
#                              coord
# 0  (57.14369, -2.0981400000000003)
# 1             (54.59633, -5.93004)
# 2             (52.51944, -1.80127)
# 3             (51.45523, -2.59665)
# 4                     (53.6, -2.3)

# %%
n = UK_covid_df.shape[0]
m = UK_pol_df.shape[0]
UK_covid_df['sensor_site_name'] = np.zeros(n)
UK_covid_df['distance from the sensor [km]'] = np.zeros(n)
dist_vect = np.zeros(m)
#associating a station to each UK_covid_df
for idx1, row1 in UK_covid_df.iterrows():
    pos1= np.array(row1['coord'])
    for idx2, row2 in UK_pol_df.iterrows():
        pos2 = np.array(row2['coord']) #position of the sensor
        dst = distance.euclidean(pos1, pos2)
        dist_vect[idx2] = dst
    idx_min = np.where(dist_vect == np.amin(dist_vect))[0][0]
    UK_covid_df.loc[idx1, 'sensor_site_name'] = UK_pol_df.loc[idx_min,'site']
    p = row1['coord'] #sensor's position
    s = UK_pol_df.loc[idx_min, 'coord'] #associated sensor position
    UK_covid_df.loc[idx1, 'distance from the sensor [km]'] = geodesic(p, s).km
# Out:
# <ipython-input-11-7b5d13be3586>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UK_covid_df['sensor_site_name'] = np.zeros(n)
# <ipython-input-11-7b5d13be3586>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UK_covid_df['distance from the sensor [km]'] = np.zeros(n)
# /usr/lib64/python3.8/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
threshold = 20
UK_covid_df = UK_covid_df[UK_covid_df['distance from the sensor [km]'] < threshold]
UK_covid_dff = UK_covid_df.groupby(['sensor_site_name'], as_index=False).agg({'# death':  np.sum})

# %%
#finally merge the two datasets
df_merged =  UK_covid_dff.merge(UK_pol_df, left_on='sensor_site_name', right_on='site')
df_merged.head()
# Out:
#     sensor_site_name  # death  Unnamed: 0               site        no2  \
# 0  Birmingham Tyburn     2355           2  Birmingham Tyburn  31.486575
# 1            Bristol      450           3            Bristol  27.290171
# 2               Bury      601           4               Bury  64.735355
# 3     Cardiff Centre      800           5     Cardiff Centre  24.618499
# 4          Carlisle       109           6          Carlisle   25.497863
#
#         pm10      pm2.5  Population                          coord
# 0  18.136199  12.977897     2916458           (52.51944, -1.80127)
# 1  17.094891  12.165736     1006600           (51.45523, -2.59665)
# 2  23.568150  18.968763     2798000                   (53.6, -2.3)
# 3  17.752360  11.066149      460800  (51.45059000000001, -3.18679)
# 4  16.736710  10.123403      498000             (54.8951, -2.9382)

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

from sklearn import decomposition
df = df_merged.drop(columns = ['sensor_site_name', 'site', 'coord'])

# Standardizse the features
df_norm = (df-df.mean())/df.std()
df_norm.head()
# Out:
#     # death  Unnamed: 0       no2      pm10     pm2.5  Population
# 0  2.988487   -1.726857  0.283023  0.033119  0.218368    2.591448
# 1 -0.310476   -1.658498 -0.003832 -0.278193 -0.103365    0.153342
# 2 -0.048983   -1.590140  2.555826  1.657064  2.591620    2.440226
# 3  0.295633   -1.521782 -0.186461 -0.081635 -0.538961   -0.543421
# 4 -0.900999   -1.453424 -0.126350 -0.385275 -0.912425   -0.495932

# %%
# Apply PCA
nc = 4
pca = decomposition.PCA(n_components=nc)
principalDf = pd.DataFrame(data = pca.fit_transform(df_norm), columns=['pc #1', 'pc #2', 'pc #3', 'pc #4'])
principalDf

import matplotlib.pyplot as plt
df = principalDf
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 


ax.scatter(df.iloc[:,0], df.iloc[:,1])

ax.grid()
ax.set_xlabel(df.columns[2], fontsize = 15)
ax.set_ylabel(df.columns[3], fontsize = 15)
ax.set_title('PCA', fontsize = 20)
plt.show()

# %%
nc = 4

# Apply PCA
pca = decomposition.PCA(n_components=nc)
PCA_df = pd.DataFrame(data = pca.fit_transform(df_norm), columns=['pc #1', 'pc #2', 'pc #3', 'pc #4'])
print("Singular values:", pca.singular_values_)
display(PCA_df)


# Append the target Label columns
target = pd.Series(np.hstack([np.zeros(nc//2),np.ones(nc//2)]) , name='label')

df = pd.concat([df, target], axis = 1)
PCA_df = pd.concat([PCA_df, target], axis = 1)
PCA_df.head()
# Out:
# Singular values: [10.69538583  6.93803866  5.93058072  5.65320243]
#        pc #1     pc #2     pc #3     pc #4
# 0   1.812557  3.511600  0.859033  1.494109
# 1  -0.200578  1.253872 -0.990994 -0.588671
# 2   4.130159  1.681649  0.149776 -1.915035
# 3  -0.359651  0.927544 -1.341800  0.198059
# 4  -1.086067  0.704040 -1.377454 -0.674906
# 5   1.046902  1.224315 -0.061250 -1.531168
# 6   0.052225  0.345763 -1.400575 -1.031737
# 7  -0.650185  0.709685 -0.791931 -0.850757
# 8  -2.086593  1.946587  0.312646 -0.451070
# 9  -0.159475  0.228026 -0.481787 -1.427478
# 10 -2.231926  0.699146 -0.938088 -0.122932
# 11  3.400660 -0.311514 -1.033241  0.863399
# 12 -1.619431 -0.076481 -0.802041 -0.271418
# 13 -0.822127 -0.180754 -0.845857  0.029793
# 14  0.674909  1.325857  0.645245  0.536995
# 15 -0.121351  0.070562 -0.316873 -0.145767
# 16 -1.037355  0.536908 -0.349633  1.446158
# 17  1.468725 -0.040754 -0.833062  1.767298
# 18  0.205071  0.029911 -0.613560  1.457486
# 19  5.023982 -1.606465 -1.567651 -0.472138
# 20  1.302435 -0.177260 -0.596382  2.088398
# 21 -1.294681  0.294655  0.438855 -0.178502
# 22 -3.821012  0.131244 -0.072096  0.336537
# 23 -1.156841 -0.048878 -0.380091  1.295976
# 24 -1.170173 -0.803534 -0.521792  0.156233
# 25 -1.177205 -0.282383  0.469497 -0.582059
# 26  0.223584 -0.531729  0.098591 -0.106631
# 27 -1.523962 -0.859669 -0.179345 -0.088870
# 28 -0.995437 -0.605254  0.302241 -0.520705
# 29  0.153428 -1.209555  0.027831 -0.197911
# 30 -0.384856  0.157357  1.431993 -0.584622
# 31 -0.888231  0.071315  1.599456 -0.798214
# 32  0.920265  1.229475  2.452518  0.890802
# 33 -0.037558 -1.338112  0.000761  0.022380
# 34  2.406989 -0.909551  1.144420 -0.422880
# 35  0.129044 -1.555761  0.087810 -0.141704
# 36  1.053435 -0.208426  1.653356  0.185980
# 37 -1.470041 -0.852642  0.930411 -0.142612
# 38  0.891996 -1.010488  1.090500 -0.074372
# 39  0.300916 -1.392007  0.953390 -0.554694
# 40 -0.030184 -1.720166  0.340382  0.162903
# 41 -0.872362 -1.358127  0.506791  0.944346
#       pc #1     pc #2     pc #3     pc #4  label
# 0  1.812557  3.511600  0.859033  1.494109    0.0
# 1 -0.200578  1.253872 -0.990994 -0.588671    0.0
# 2  4.130159  1.681649  0.149776 -1.915035    1.0
# 3 -0.359651  0.927544 -1.341800  0.198059    1.0
# 4 -1.086067  0.704040 -1.377454 -0.674906    NaN
